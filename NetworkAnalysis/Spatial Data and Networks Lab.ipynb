# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from nose.tools import *

from mpl_toolkits.basemap import Basemap

import networkx as nx

# %% [markdown]
# # Working with Spatial Data and Networks Lab
# ## Preparing data, extracting features, visualization and modelling

# %% [markdown]
# In this lab we'll explore terrorism, as described in [this](https://www.kaggle.com/START-UMD/gtd) dataset.
#
# The full codebook, describing all variables, their values, the data collection process, and many more details, is located [here](http://start.umd.edu/gtd/downloads/Codebook.pdf).
#
# We'll perform our usual process:
# * Reading and inspecting the data
# * Validating the data
# * Exploring the data
# * Creating inferences and getting to conclusions

# %% [markdown]
# ### 1. Read the dataset (1 point)
# The dataset is provided in the `data` folder. Read it into Python. You'll likely get an encoding error, so you can use `encoding = "cp1252"`.
#
# Use the column `eventid` as the index, since this is a good unique identifier and it's used in the dataset (e.g. the column `related` contains the `eventid` of all related crimes).
#
# You'll see the dataset has a lot of columns. For this lab, we aren't going to need all of them, only a few. Select these columns (and rename them as described in the tests below):
# * eventid
# * iyear, imonth, iday
# * country_txt
# * region_txt
# * multiple (1 if it's a part of a multiple incident and 0 otherwise)
# * latitude, longitude
# * targtype1_txt (first target type)
# * weaptype1_text (weapon type)
# * gname (perpetrator group name)
# * nkill (total number of fatalities)
# * related (IDs of the related incidents)
#
# You'll have a total of 12 columns (the eventid which will become an index is not considered a typical column in a dataframe) and just over 170 thousand records.

# %%
terrorism_data = pd.read_csv("data/globalterrorismdb.csv", encoding = "cp1252", low_memory = False)
terrorism_data.set_index('eventid', inplace = True)
terrorism_data.head()
# Out:
#               iyear  imonth  iday approxdate  extended resolution  country  \
# eventid
# 197000000001   1970       7     2        NaN         0        NaN       58
# 197000000002   1970       0     0        NaN         0        NaN      130
# 197001000001   1970       1     0        NaN         0        NaN      160
# 197001000002   1970       1     0        NaN         0        NaN       78
# 197001000003   1970       1     0        NaN         0        NaN      101
#
#                      country_txt  region                   region_txt  \
# eventid
# 197000000001  Dominican Republic       2  Central America & Caribbean
# 197000000002              Mexico       1                North America
# 197001000001         Philippines       5               Southeast Asia
# 197001000002              Greece       8               Western Europe
# 197001000003               Japan       4                    East Asia
#
#                ...    addnotes scite1  scite2  scite3  dbsource  INT_LOG  \
# eventid        ...
# 197000000001   ...         NaN    NaN     NaN     NaN      PGIS        0
# 197000000002   ...         NaN    NaN     NaN     NaN      PGIS        0
# 197001000001   ...         NaN    NaN     NaN     NaN      PGIS       -9
# 197001000002   ...         NaN    NaN     NaN     NaN      PGIS       -9
# 197001000003   ...         NaN    NaN     NaN     NaN      PGIS       -9
#
#              INT_IDEO INT_MISC  INT_ANY  related
# eventid
# 197000000001        0        0        0      NaN
# 197000000002        1        1        1      NaN
# 197001000001       -9        1        1      NaN
# 197001000002       -9        1        1      NaN
# 197001000003       -9        1        1      NaN
#
# [5 rows x 134 columns]

# %%
terrorism_data = terrorism_data[['iyear', 'imonth', 'iday', 'country_txt', 'region_txt', 'multiple', 'latitude', 'longitude', 'targtype1_txt', 'weaptype1_txt', 'gname', 'nkill', 'related']]
terrorism_data.columns = ["year", "month", "day", "country", "region", "multiple", "latitude", "longitude", "target_type", "weapon_type", "group_name", "fatalities", "related"]
terrorism_data.head()
# Out:
#               year  month  day             country  \
# eventid
# 197000000001  1970      7    2  Dominican Republic
# 197000000002  1970      0    0              Mexico
# 197001000001  1970      1    0         Philippines
# 197001000002  1970      1    0              Greece
# 197001000003  1970      1    0               Japan
#
#                                    region  multiple   latitude   longitude  \
# eventid
# 197000000001  Central America & Caribbean         0  18.456792  -69.951164
# 197000000002                North America         0  19.432608  -99.133207
# 197001000001               Southeast Asia         0  15.478598  120.599741
# 197001000002               Western Europe         0  37.983773   23.728157
# 197001000003                    East Asia         0  33.580412  130.396361
#
#                               target_type                weapon_type  \
# eventid
# 197000000001  Private Citizens & Property                    Unknown
# 197000000002      Government (Diplomatic)                    Unknown
# 197001000001          Journalists & Media                    Unknown
# 197001000002      Government (Diplomatic)  Explosives/Bombs/Dynamite
# 197001000003      Government (Diplomatic)                 Incendiary
#
#                                       group_name  fatalities related
# eventid
# 197000000001                              MANO-D         1.0     NaN
# 197000000002  23rd of September Communist League         0.0     NaN
# 197001000001                             Unknown         1.0     NaN
# 197001000002                             Unknown         NaN     NaN
# 197001000003                             Unknown         NaN     NaN

# %%
assert_is_not_none(terrorism_data)
assert_list_equal(terrorism_data.columns.tolist(), ["year", "month", "day", "country", "region", "multiple", "latitude", "longitude", "target_type", "weapon_type", "group_name", "fatalities", "related"])

# %% [markdown]
# ### 2. Convert columns (1 point)
# Convert the "year", "month" and "day" columns into a single date. Call the new column "date".
#
# Note that some months and/or days contain 0 as their values. This means that the exact month or day is not present or known. In these cases, write "not a time" (NaT) values in the "date" column. Do not remove those records!
#
# Also, convert the "multiple" column into a Boolean one.

# %%
terrorism_data['date'] = pd.to_datetime(terrorism_data.day + (terrorism_data.month * 100) + (terrorism_data.year * 10000), format = '%Y%m%d', errors = 'coerce')
terrorism_data
# Out:
#               year  month  day                           country  \
# eventid
# 197000000001  1970      7    2                Dominican Republic
# 197000000002  1970      0    0                            Mexico
# 197001000001  1970      1    0                       Philippines
# 197001000002  1970      1    0                            Greece
# 197001000003  1970      1    0                             Japan
# 197001010002  1970      1    1                     United States
# 197001020001  1970      1    2                           Uruguay
# 197001020002  1970      1    2                     United States
# 197001020003  1970      1    2                     United States
# 197001030001  1970      1    3                     United States
# 197001050001  1970      1    1                     United States
# 197001060001  1970      1    6                     United States
# 197001080001  1970      1    8                             Italy
# 197001090001  1970      1    9                     United States
# 197001090002  1970      1    9                     United States
# 197001100001  1970      1   10                East Germany (GDR)
# 197001110001  1970      1   11                          Ethiopia
# 197001120001  1970      1   12                     United States
# 197001120002  1970      1   12                     United States
# 197001130001  1970      1   13                     United States
# 197001140001  1970      1   14                     United States
# 197001150001  1970      1   15                           Uruguay
# 197001190002  1970      1   19                     United States
# 197001190003  1970      1   19                     United States
# 197001190004  1970      1   19                     United States
# 197001200001  1970      1   20                         Guatemala
# 197001210001  1970      1   21                       Philippines
# 197001220001  1970      1   22                         Venezuela
# 197001220002  1970      1   22                     United States
# 197001250001  1970      1   25                     United States
# ...            ...    ...  ...                               ...
# 201612310011  2016     12   31                       Philippines
# 201612310012  2016     12   31                        Bangladesh
# 201612310013  2016     12   30                          Pakistan
# 201612310014  2016     12   31                      Saudi Arabia
# 201612310015  2016     12   31                       Afghanistan
# 201612310016  2016     12   31                           Burundi
# 201612310017  2016     12   31                          Pakistan
# 201612310019  2016     12   31                             India
# 201612310022  2016     12   31                       Afghanistan
# 201612310023  2016     12   31                       Afghanistan
# 201612310024  2016     12   31                           Nigeria
# 201612310025  2016     12   31                              Iraq
# 201612310026  2016     12   31                              Iraq
# 201612310027  2016     12   31                              Iraq
# 201612310028  2016     12   31                              Iraq
# 201612310029  2016     12   31                              Iraq
# 201612310030  2016     12   31                              Iraq
# 201612310031  2016     12   31                              Iraq
# 201612310033  2016     12   31                          Pakistan
# 201612310034  2016     12   31                       Afghanistan
# 201612310035  2016     12   31                       Afghanistan
# 201612310036  2016     12   31                       Afghanistan
# 201612310037  2016     12   31                       Afghanistan
# 201612310038  2016     12   30                       Afghanistan
# 201612310039  2016     12   31                       Afghanistan
# 201612310040  2016     12   31                             Niger
# 201612310042  2016     12   31                       Philippines
# 201612310043  2016     12   31  Democratic Republic of the Congo
# 201612310044  2016     12   31                            Mexico
# 201701270001  2016     12   30                             Sudan
#
#                                    region  multiple   latitude   longitude  \
# eventid
# 197000000001  Central America & Caribbean         0  18.456792  -69.951164
# 197000000002                North America         0  19.432608  -99.133207
# 197001000001               Southeast Asia         0  15.478598  120.599741
# 197001000002               Western Europe         0  37.983773   23.728157
# 197001000003                    East Asia         0  33.580412  130.396361
# 197001010002                North America         0  37.005105  -89.176269
# 197001020001                South America         0 -34.891151  -56.187214
# 197001020002                North America         0  37.805065 -122.273024
# 197001020003                North America         0  43.076592  -89.412488
# 197001030001                North America         0  43.072950  -89.386694
# 197001050001                North America         0  43.468500  -89.744299
# 197001060001                North America         0  39.740010 -104.992259
# 197001080001               Western Europe         0  41.890520   12.494249
# 197001090001                North America         0  42.331685  -83.047924
# 197001090002                North America         0  18.399712  -66.049987
# 197001100001               Eastern Europe         0  52.516667   13.400000
# 197001110001           Sub-Saharan Africa         0        NaN         NaN
# 197001120001                North America         0  40.610069  -73.947971
# 197001120002                North America         0  18.379998  -65.830948
# 197001130001                North America         0  47.603560 -122.329439
# 197001140001                North America         0  40.116748  -88.239270
# 197001150001                South America         0 -34.891151  -56.187214
# 197001190002                North America         0  47.610594 -122.317228
# 197001190003                North America         0  47.655335 -122.303520
# 197001190004                North America         0  40.728075  -74.077825
# 197001200001  Central America & Caribbean         0  14.624422  -90.532880
# 197001210001               Southeast Asia         0  14.677301  121.044348
# 197001220001                South America         0  10.502961  -66.917253
# 197001220002                North America         0  42.470310  -96.413949
# 197001250001                North America         0  33.606510  -88.650419
# ...                                   ...       ...        ...         ...
# 201612310011               Southeast Asia         0   6.957127  124.474408
# 201612310012                   South Asia         0  25.564362   89.519090
# 201612310013                   South Asia         0  30.661181   73.108576
# 201612310014   Middle East & North Africa         0  16.889359   42.570567
# 201612310015                   South Asia         0  34.533342   69.078022
# 201612310016           Sub-Saharan Africa         0  -3.253245   29.430266
# 201612310017                   South Asia         0  34.014975   71.580490
# 201612310019                   South Asia         0  24.806454   93.920810
# 201612310022                   South Asia         0  32.372459   62.120092
# 201612310023                   South Asia         0  34.221242   69.078024
# 201612310024           Sub-Saharan Africa         0  11.831098   13.150967
# 201612310025   Middle East & North Africa         0  34.345164   44.467121
# 201612310026   Middle East & North Africa         0  33.381146   44.344940
# 201612310027   Middle East & North Africa         1  33.332813   44.401060
# 201612310028   Middle East & North Africa         1  33.332813   44.401060
# 201612310029   Middle East & North Africa         0  33.305081   44.488947
# 201612310030   Middle East & North Africa         0  33.370243   44.278691
# 201612310031   Middle East & North Africa         0  36.352632   43.190460
# 201612310033                   South Asia         0  33.803879   72.025434
# 201612310034                   South Asia         1  36.662402   65.748508
# 201612310035                   South Asia         1  36.667981   65.751084
# 201612310036                   South Asia         1  36.666222   65.754795
# 201612310037                   South Asia         1  36.659695   65.752408
# 201612310038                   South Asia         0  37.007020   66.026738
# 201612310039                   South Asia         0  31.583664   64.368699
# 201612310040           Sub-Saharan Africa         0  13.883032   13.177504
# 201612310042               Southeast Asia         0   7.027067  124.386552
# 201612310043           Sub-Saharan Africa         0   4.308611   25.091389
# 201612310044                North America         0  26.819644 -107.069898
# 201701270001           Sub-Saharan Africa         0  12.961401   24.044116
#
#                                  target_type                weapon_type  \
# eventid
# 197000000001     Private Citizens & Property                    Unknown
# 197000000002         Government (Diplomatic)                    Unknown
# 197001000001             Journalists & Media                    Unknown
# 197001000002         Government (Diplomatic)  Explosives/Bombs/Dynamite
# 197001000003         Government (Diplomatic)                 Incendiary
# 197001010002                          Police                   Firearms
# 197001020001                          Police                   Firearms
# 197001020002                       Utilities  Explosives/Bombs/Dynamite
# 197001020003                        Military                 Incendiary
# 197001030001            Government (General)                 Incendiary
# 197001050001                        Military  Explosives/Bombs/Dynamite
# 197001060001                        Military                 Incendiary
# 197001080001             Airports & Aircraft                   Firearms
# 197001090001            Government (General)                 Incendiary
# 197001090002                        Business                 Incendiary
# 197001100001            Government (General)  Explosives/Bombs/Dynamite
# 197001110001                        Military                    Unknown
# 197001120001         Educational Institution  Explosives/Bombs/Dynamite
# 197001120002                        Business  Explosives/Bombs/Dynamite
# 197001130001                        Business                 Incendiary
# 197001140001                          Police                 Incendiary
# 197001150001         Educational Institution                   Firearms
# 197001190002         Educational Institution  Explosives/Bombs/Dynamite
# 197001190003                        Military  Explosives/Bombs/Dynamite
# 197001190004         Violent Political Party                 Incendiary
# 197001200001         Government (Diplomatic)                    Unknown
# 197001210001         Government (Diplomatic)  Explosives/Bombs/Dynamite
# 197001220001                        Business                    Unknown
# 197001220002     Private Citizens & Property  Explosives/Bombs/Dynamite
# 197001250001     Private Citizens & Property                 Incendiary
# ...                                      ...                        ...
# 201612310011                        Military                   Firearms
# 201612310012            Government (General)                   Firearms
# 201612310013                          Police                   Firearms
# 201612310014                        Military  Explosives/Bombs/Dynamite
# 201612310015     Private Citizens & Property  Explosives/Bombs/Dynamite
# 201612310016  Religious Figures/Institutions  Explosives/Bombs/Dynamite
# 201612310017     Private Citizens & Property                   Firearms
# 201612310019                        Business  Explosives/Bombs/Dynamite
# 201612310022                          Police                   Firearms
# 201612310023                        Military                   Firearms
# 201612310024     Private Citizens & Property  Explosives/Bombs/Dynamite
# 201612310025                        Military                    Unknown
# 201612310026     Private Citizens & Property  Explosives/Bombs/Dynamite
# 201612310027     Private Citizens & Property  Explosives/Bombs/Dynamite
# 201612310028     Private Citizens & Property  Explosives/Bombs/Dynamite
# 201612310029     Private Citizens & Property  Explosives/Bombs/Dynamite
# 201612310030     Private Citizens & Property  Explosives/Bombs/Dynamite
# 201612310031                        Military  Explosives/Bombs/Dynamite
# 201612310033                          Police                   Firearms
# 201612310034                        Military                    Unknown
# 201612310035                        Military                    Unknown
# 201612310036                        Military                    Unknown
# 201612310037                        Military                    Unknown
# 201612310038    Terrorists/Non-State Militia  Explosives/Bombs/Dynamite
# 201612310039     Private Citizens & Property  Explosives/Bombs/Dynamite
# 201612310040                        Military                    Unknown
# 201612310042                             NGO  Explosives/Bombs/Dynamite
# 201612310043     Private Citizens & Property                    Unknown
# 201612310044             Journalists & Media                   Firearms
# 201701270001     Private Citizens & Property                   Firearms
#
#                                                      group_name  fatalities  \
# eventid
# 197000000001                                             MANO-D         1.0
# 197000000002                 23rd of September Communist League         0.0
# 197001000001                                            Unknown         1.0
# 197001000002                                            Unknown         NaN
# 197001000003                                            Unknown         NaN
# 197001010002                                 Black Nationalists         0.0
# 197001020001                                Tupamaros (Uruguay)         0.0
# 197001020002                                            Unknown         0.0
# 197001020003                                    New Year's Gang         0.0
# 197001030001                                    New Year's Gang         0.0
# 197001050001                    Weather Underground, Weathermen         0.0
# 197001060001                                Left-Wing Militants         0.0
# 197001080001                                            Unknown         0.0
# 197001090001                                Left-Wing Militants         0.0
# 197001090002                      Armed Commandos of Liberation         0.0
# 197001100001                                          Commune 1         NaN
# 197001110001                          Eritrean Liberation Front         1.0
# 197001120001                                 Black Nationalists         0.0
# 197001120002                                           Strikers         0.0
# 197001130001                                 Black Nationalists         0.0
# 197001140001                                 Black Nationalists         0.0
# 197001150001                                Tupamaros (Uruguay)         0.0
# 197001190002                                 Black Nationalists         0.0
# 197001190003                                   Student Radicals         0.0
# 197001190004                                   White extremists         0.0
# 197001200001                                            Unknown         1.0
# 197001210001                                            Unknown         0.0
# 197001220001  Armed Forces of National Liberation- Venezuela...         0.0
# 197001220002                                           Strikers         0.0
# 197001250001                                   White extremists         0.0
# ...                                                         ...         ...
# 201612310011         Bangsamoro Islamic Freedom Movement (BIFM)         0.0
# 201612310012                       Jamaat-E-Islami (Bangladesh)         1.0
# 201612310013                                            Unknown         0.0
# 201612310014                    Houthi extremists (Ansar Allah)         1.0
# 201612310015                                            Unknown         2.0
# 201612310016                                            Unknown         0.0
# 201612310017                                            Unknown         1.0
# 201612310019                                            Unknown         0.0
# 201612310022                                            Unknown         0.0
# 201612310023                                            Unknown         1.0
# 201612310024                                         Boko Haram         2.0
# 201612310025        Islamic State of Iraq and the Levant (ISIL)         3.0
# 201612310026                                            Unknown         2.0
# 201612310027        Islamic State of Iraq and the Levant (ISIL)        15.0
# 201612310028        Islamic State of Iraq and the Levant (ISIL)        15.0
# 201612310029                                            Unknown         4.0
# 201612310030                                            Unknown         1.0
# 201612310031        Islamic State of Iraq and the Levant (ISIL)         NaN
# 201612310033                                            Unknown         2.0
# 201612310034                                            Taliban         1.0
# 201612310035                                            Taliban         1.0
# 201612310036                                            Taliban         0.0
# 201612310037                                            Taliban         0.0
# 201612310038                                            Taliban         2.0
# 201612310039                                            Unknown         1.0
# 201612310040                                         Boko Haram        15.0
# 201612310042                                            Unknown         0.0
# 201612310043                       Lord's Resistance Army (LRA)         0.0
# 201612310044                                            Unknown         0.0
# 201701270001                          Sudan Liberation Movement         0.0
#
#                                                         related       date
# eventid
# 197000000001                                                NaN 1970-07-02
# 197000000002                                                NaN        NaT
# 197001000001                                                NaN        NaT
# 197001000002                                                NaN        NaT
# 197001000003                                                NaN        NaT
# 197001010002                                                NaN 1970-01-01
# 197001020001                                                NaN 1970-01-02
# 197001020002                                                NaN 1970-01-02
# 197001020003                                                NaN 1970-01-02
# 197001030001                                                NaN 1970-01-03
# 197001050001                                                NaN 1970-01-01
# 197001060001                                                NaN 1970-01-06
# 197001080001                                                NaN 1970-01-08
# 197001090001                                                NaN 1970-01-09
# 197001090002                                                NaN 1970-01-09
# 197001100001                                                NaN 1970-01-10
# 197001110001                                                NaN 1970-01-11
# 197001120001                                                NaN 1970-01-12
# 197001120002                                                NaN 1970-01-12
# 197001130001                                                NaN 1970-01-13
# 197001140001                                                NaN 1970-01-14
# 197001150001                                                NaN 1970-01-15
# 197001190002                                                NaN 1970-01-19
# 197001190003                                                NaN 1970-01-19
# 197001190004                                                NaN 1970-01-19
# 197001200001                                                NaN 1970-01-20
# 197001210001                                                NaN 1970-01-21
# 197001220001                                                NaN 1970-01-22
# 197001220002                                                NaN 1970-01-22
# 197001250001                                                NaN 1970-01-25
# ...                                                         ...        ...
# 201612310011                                                NaN 2016-12-31
# 201612310012                                                NaN 2016-12-31
# 201612310013                                                NaN 2016-12-30
# 201612310014                                                NaN 2016-12-31
# 201612310015                                                NaN 2016-12-31
# 201612310016                                                NaN 2016-12-31
# 201612310017                                                NaN 2016-12-31
# 201612310019                                                NaN 2016-12-31
# 201612310022                                                NaN 2016-12-31
# 201612310023                                                NaN 2016-12-31
# 201612310024                                                NaN 2016-12-31
# 201612310025                                                NaN 2016-12-31
# 201612310026                                                NaN 2016-12-31
# 201612310027                         201612310027, 201612310028 2016-12-31
# 201612310028                         201612310027, 201612310028 2016-12-31
# 201612310029                                                NaN 2016-12-31
# 201612310030                                                NaN 2016-12-31
# 201612310031                                                NaN 2016-12-31
# 201612310033                                                NaN 2016-12-31
# 201612310034  201612310034, 201612310035, 201612310036, 2016... 2016-12-31
# 201612310035  201612310034, 201612310035, 201612310036, 2016... 2016-12-31
# 201612310036  201612310034, 201612310035, 201612310036, 2016... 2016-12-31
# 201612310037  201612310034, 201612310035, 201612310036, 2016... 2016-12-31
# 201612310038                                                NaN 2016-12-30
# 201612310039                                                NaN 2016-12-31
# 201612310040                                                NaN 2016-12-31
# 201612310042                                                NaN 2016-12-31
# 201612310043                                                NaN 2016-12-31
# 201612310044                                                NaN 2016-12-31
# 201701270001                                                NaN 2016-12-30
#
# [170350 rows x 14 columns]

# %%
terrorism_data.date.dtype
# Out:
# dtype('<M8[ns]')

# %%
terrorism_data.multiple = terrorism_data.multiple.astype(bool)
terrorism_data.multiple.dtype
# Out:
# dtype('bool')

# %%
# remove unnecesary columns
terrorism_data.drop(["day", "month", "year"], axis = 1, inplace = True)
terrorism_data.head()
# Out:
#                          country                       region  multiple  \
# eventid
# 197000000001  Dominican Republic  Central America & Caribbean     False
# 197000000002              Mexico                North America     False
# 197001000001         Philippines               Southeast Asia     False
# 197001000002              Greece               Western Europe     False
# 197001000003               Japan                    East Asia     False
#
#                latitude   longitude                  target_type  \
# eventid
# 197000000001  18.456792  -69.951164  Private Citizens & Property
# 197000000002  19.432608  -99.133207      Government (Diplomatic)
# 197001000001  15.478598  120.599741          Journalists & Media
# 197001000002  37.983773   23.728157      Government (Diplomatic)
# 197001000003  33.580412  130.396361      Government (Diplomatic)
#
#                             weapon_type                          group_name  \
# eventid
# 197000000001                    Unknown                              MANO-D
# 197000000002                    Unknown  23rd of September Communist League
# 197001000001                    Unknown                             Unknown
# 197001000002  Explosives/Bombs/Dynamite                             Unknown
# 197001000003                 Incendiary                             Unknown
#
#               fatalities related       date
# eventid
# 197000000001         1.0     NaN 1970-07-02
# 197000000002         0.0     NaN        NaT
# 197001000001         1.0     NaN        NaT
# 197001000002         NaN     NaN        NaT
# 197001000003         NaN     NaN        NaT

# %%
assert_greater(len(terrorism_data.date), 0)
assert_equal(terrorism_data.multiple.dtype, np.bool)

# %% [markdown]
# ### 3. Show how the number of attacks evolves with time (1 point)
# Group all incidents by year. Create a line plot showing how the attacks evolve.
#
# Create a function which accepts a dataframe and returns the years with minimum and maximum incidents.
#
# Use this function to see the numbers for your dataset.

# %%
attacks_by_year = terrorism_data.groupby(terrorism_data.date.dt.year)['country'].count()
attacks_by_year.shape
# Out:
# (46,)

# %%
plt.plot(attacks_by_year.index, attacks_by_year.values, color = 'r')
plt.xlabel('Years')
plt.ylabel('Attacks')
plt.show()

# %%
def get_max_and_min_incidents_years(dataframe):

    grouped = dataframe.groupby(dataframe.date.dt.year)['country'].count()
    min_incidents_year = grouped.idxmin()
    max_incidents_year = grouped.idxmax()
    
    return (min_incidents_year, max_incidents_year)

# %%
min_year, max_year = get_max_and_min_incidents_years(terrorism_data)
assert_equal(min_year, 1971)
assert_equal(max_year, 2014)

# %% [markdown]
# ### 4. Filter terror attacks (1 point)
# Get only recent attacks (from 1 Jan 2000 onwards, inclusive). Save them in the variable `recent_attacks`.
#
# Create another variable which contains attacks before that. Call that `older_attacks`.
#
# We'll compare these later.

# %%
recent_attacks = terrorism_data[terrorism_data.date.dt.year >= 2000]
older_attacks = terrorism_data[terrorism_data.date.dt.year < 2000]

# %%
assert_is_not_none(recent_attacks)
assert_is_not_none(older_attacks)

# %% [markdown]
# ### 5. Compare recent to older attacks (1 point)
# Create a function which accepts a dataframe and returns a `Series`. The index should be a country name, and the values should be the number of  attacks. Sort the values from highest to lowest.

# %%
def get_num_attacks_by_country(dataframe):
    
    grouped = dataframe.groupby(['country'])['country'].count()
    return grouped.sort_values(ascending = False).head(10)

# %%
recent_attacks_by_country = get_num_attacks_by_country(recent_attacks)
older_attacks_by_country = get_num_attacks_by_country(older_attacks)
print(recent_attacks_by_country)
print(older_attacks_by_country)
assert_equal(recent_attacks_by_country.shape, (10,))
assert_equal(older_attacks_by_country.shape, (10,))
# Out:
# country
# Iraq           21951
# Pakistan       11782
# Afghanistan    11169
# India           7916
# Philippines     4218
# Thailand        3437
# Nigeria         3337
# Somalia         3305
# Yemen           3001
# Libya           2039
# Name: country, dtype: int64
# country
# Colombia          6160
# Peru              5986
# El Salvador       5277
# United Kingdom    4144
# India             3033
# Spain             2793
# Turkey            2466
# United States     2327
# Chile             2262
# France            2189
# Name: country, dtype: int64

# %%
def show_graph(num_attacks, title):
    plt.bar(range(len(num_attacks)), num_attacks)
    plt.xticks(range(len(num_attacks)), num_attacks.index, rotation = "vertical")
    plt.title(title)
    plt.show()

show_graph(older_attacks_by_country, "Older attacks (before 2000)")
show_graph(recent_attacks_by_country, "Recent attacks (since 2000)")

# %% [markdown]
# We can see that these attacks definitely changed very much. First, there are many more since 2000, and second, the top targeted countries have changed a lot: only India remains in the top chart (execute the following cell if you don't believe me).

# %%
set(recent_attacks_by_country.index).intersection(set(older_attacks_by_country.index))
# Out:
# {'India'}

# %% [markdown]
# There's a lot more to explore in the data, but let's focus on the spatial aspect.

# %% [markdown]
# ### 6. Create a basic map (2 points)
# Plot all places where terrorist attacks have occurred.
#
# The skeleton below almost does the job. What you need to do is: first, convert the geographical coordinates to horizontal and assign them to the `x` and `y` variables; second, create a scatter plot, using a red circle (`"o"`), with marker size 1.

# %%
plt.figure(figsize = (12, 10))
m = Basemap(projection = "merc", llcrnrlat = -73, llcrnrlon = -180, urcrnrlat = 80, urcrnrlon = 180)
x, y = m(terrorism_data.longitude.tolist(), terrorism_data.latitude.tolist())

m.plot(x, y, "o", markersize = 1, color = "red")
m.drawcoastlines()
m.drawcountries()
m.fillcontinents(color = "lightgreen", lake_color = "aqua")
m.drawmapboundary(fill_color = "aqua")

plt.show()
# Out:
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1698: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch

# %%
assert_is_not_none(x)
assert_is_not_none(y)

# %% [markdown]
# ### 7. Emphasize incidents which are part of a group
# Redraw the map above. This time, filter out the attacks which are part of a series (this is contained in the column `multiple`). Show them on the map with an orange color.

# %%
single_attacks = terrorism_data[terrorism_data.multiple == False]
multiple_attacks = terrorism_data[terrorism_data.multiple == True]

# %%
plt.figure(figsize = (12, 10))
m = Basemap(projection = "merc", llcrnrlat = -73, llcrnrlon = -180, urcrnrlat = 80, urcrnrlon = 180)

x, y = m(single_attacks.longitude.tolist(), single_attacks.latitude.tolist())
m.plot(x, y, "o", markersize = 1, color = "red")

x, y = m(multiple_attacks.longitude.tolist(), multiple_attacks.latitude.tolist())
m.plot(x, y, "o", markersize = 1, color = "orange")

m.drawcoastlines()
m.drawcountries()
m.fillcontinents(color = "lightgreen", lake_color = "aqua")
m.drawmapboundary(fill_color = "aqua")
plt.show()
# Out:
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1698: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch

# %% [markdown]
# You can see that a lot of the attacks are parts of series, possibly organized. But, remember that we have a point on the map for every single attack. If we see how many multiple attacks there are (as a fraction of the whole), we'll get about 13.4%:

# %%
len(multiple_attacks) / len(terrorism_data)
# Out:
# 0.13420604637511008

# %% [markdown]
# The plot we made was a little misleading. We're displaying where attacks occur but we omitted the "density" of attacks: each location gets a point no matter whether there was one incident, or ten thousand in that point.
#
# We can try plotting the densities instead.

# %% [markdown]
# ### 8. Plot attack densities (1 point)
# First, we need to filter out attacks with unknown (NaN) location. Do this and save it in the variable `attacks_with_locations`.
#
# The following cell prints a 2D histogram (also called a heatmap) over the world map. Execute it, it should run just fine.

# %%
attacks_with_locations = terrorism_data[pd.notnull(terrorism_data.longitude) & pd.notnull(terrorism_data.latitude)]
attacks_with_locations.shape
# Out:
# (165744, 11)

# %%
def plot_attack_densities(attack_data, title = "Attack densities"):
    plt.figure(figsize = (15, 10))
    m = Basemap(projection = "merc", llcrnrlat = -73, llcrnrlon = -180, urcrnrlat = 80, urcrnrlon = 180)

    # Prepare histogram bins
    num_bins = 100
    lon_bins = np.linspace(-180, 180, num_bins + 1)
    lat_bins = np.linspace(-90, 90, num_bins + 1)

    # Create 2D histogram values
    density, x_breaks, y_breaks = np.histogram2d(
        attack_data.latitude,
        attack_data.longitude, 
        [lat_bins, lon_bins])

    # Create the basis of the histogram - the (x, y) value pairs
    # and map them to 2D distances
    lon_bins_2d, lat_bins_2d = np.meshgrid(lon_bins, lat_bins)
    x, y = m(lon_bins_2d, lat_bins_2d)

    m.drawcoastlines()
    m.drawcountries()
    m.pcolormesh(x, y, density)
    m.colorbar()
    plt.title(title)
    plt.show()

# %%
plot_attack_densities(attacks_with_locations)
# Out:
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3413: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3422: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %% [markdown]
# We can see various "hot points". The hottest one, as expected from the data above, is Iraq. Actually, it has so many attacks that it overshadows most of the data in our dataset.
#
# Let's remove it and plot the data again. This is a way to estimate **importance** of something (although not a very scientific one :)).

# %%
attacks_without_iraq = attacks_with_locations[attacks_with_locations.country != 'Iraq']
attacks_without_iraq.shape
# Out:
# (143757, 11)

# %%
assert_is_not_none(attacks_with_locations)
assert_is_not_none(attacks_without_iraq)

# %%
plot_attack_densities(attacks_without_iraq, "Attack densities (Iraq omitted)")
# Out:
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3413: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/stanislavdimitrov/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3422: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %% [markdown]
# Well, the map "lit up". Notice that the colorbar now shows completely different values.
#
# Based on these visualizations, we can conclude that the number of attacks in Iraq is really significant compared to all others.
#
# We're also able to see more hot points now, and we may try to interpret them. However, that's not what we're going to do.

# %% [markdown]
# ### 9. Create a graph of connected incidents (1 point)
# We already have incidents which are part of groups: the variable `multiple_attacks` holds them.
#
# However, it turns out that some of these hold NaNs in the `related` column.
#
# Create a new dataset which holds the `eventid` and `related` incidents of every attack in `multiple_attacks`.
#
# Filter the dataset so that it contains only valid (i.e. non-empty or NaN) `related` values.
#
# Store this dataset into `incident_relations`.

# %%
incident_relations = multiple_attacks[['related']]
incident_relations = incident_relations[pd.notnull(incident_relations.related)]
incident_relations.shape
# Out:
# (22840, 1)

# %%
assert_equal(incident_relations.shape, (22840, 1))

# %% [markdown]
# Get all relations by splitting the column first, like so:
# ```
# relations = incident_relations.related.str.split(", ")
# ```
#
# For each relation, if the id of the first and second node aren't the same, add the relation as an edge. An edge has the format `(id_1, id_2)`.
#
# The code is not very hard to understand but it definitely IS tricky to write. So I'm giving it to you for free :).

# %%
edges = set()

relations = incident_relations.related.str.split("\D+")
for index, related in relations.iteritems():
    current_index = int(index)
    for related_id in related:
        if related_id != "":
            current_related = int(related_id)
            # (id_1, id_2) and (id_2, id_1) should be considered the same
            # undirected edge but in the dataset, they are separate
            # so we need to avoid double-adding edges
            if current_index == current_related:
                continue
            elif current_index > current_related:
                current_index, current_related = current_related, current_index
            edges.add((current_index, current_related))
print(len(edges))
# Out:
# 16452

# %% [markdown]
# Create a graph, `attack_graph` and add all edges that you (or I :D) just calculated to it.
#
# Beware: visualization will take a lot of time. I'm only testing basic properties on the graph.

# %%
attack_graph = nx.Graph()
attack_graph.add_edges_from(edges)

# %%
#plt.figure(figsize = (30, 30))
nx.draw(attack_graph, with_labels = True)

plt.show()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
assert_is_not_none(attack_graph)
